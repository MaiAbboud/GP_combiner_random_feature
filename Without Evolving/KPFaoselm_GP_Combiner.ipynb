# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.utils import shuffle
from tqdm.notebook import tqdm
from random import shuffle
from time import time
import sys
import graphviz
import os

# %%
root_path = '/home/maiabboud/Documents/RACHIS/GP_Combiner/GP_combiner_random_feature'
data_path = os.path.join(root_path, 'data')
code_path = os.path.join(root_path, 'Shared Codes')
results_path = os.path.join(root_path, 'Results')

sys.path.insert(0,code_path)
from oselm import set_use_know
from SharedFunctions import main, generate_oselm_models

# %%
filename = ['ISCX2012.csv']
filename = list(map(lambda x: os.path.join(data_path, x), filename))
data_name = ['ISCX2012']

# %%
ChunkNumber=0
use_know = True
set_use_know(use_know)
path = os.path.join(results_path,'kpfaoselm_gp_combiner_with_model_replacement')
os.makedirs(path, exist_ok=True)
f_name,d_name = filename[0] , data_name[0]
DFS_results_path = os.path.join(results_path,d_name)
main(f_name, generate_oselm_models, apply_model_replacement=True,transfer_learning=True,
     feature_selection=["with_out_feature_evolving",''], result_save_path=path,
     DFS_results_path=DFS_results_path,ChunkNumber=ChunkNumber,is_synthetic=True,chunk_size = 1000)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ===================== dataset : ISCX2012.csv ======================
# 0it [00:00, ?it/s]
# Without Any FS
# 1 {'accuracy': 0.8585365853658536, 'precision': 1.0, 'recall': 0.7314814814814815, 'f1-score': 0.8449197860962567, 'auc': 0.8657407407407407}
# Without Any FS
# 2 {'accuracy': 0.8275862068965517, 'precision': 1.0, 'recall': 0.6982758620689655, 'f1-score': 0.8223350253807107, 'auc': 0.8491379310344828}
# Without Any FS
# 3 {'accuracy': 0.8428571428571429, 'precision': 1.0, 'recall': 0.6764705882352942, 'f1-score': 0.8070175438596492, 'auc': 0.8382352941176471}
# Without Any FS
# 4 {'accuracy': 0.8811881188118812, 'precision': 1.0, 'recall': 0.7446808510638298, 'f1-score': 0.8536585365853657, 'auc': 0.8723404255319149}
# Without Any FS
# 5 {'accuracy': 0.8578431372549019, 'precision': 0.9879518072289156, 'recall': 0.7454545454545455, 'f1-score': 0.8497409326424871, 'auc': 0.8674081237911027}
# Without Any FS
# ...
